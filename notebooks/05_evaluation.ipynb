# %% [markdown]
# # 05 - Evaluation
#
# **CRISP-DM Phase 5: Evaluation**
#
# Evaluate model performance and generate reports.

# %%
import pandas as pd
import sys, os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from modeling.xgb_regressor import XGBoostRULRegressor
from modeling.xgb_classifier import XGBoostFailureClassifier
from evaluation.regression_metrics import evaluate_regression
from evaluation.classification_metrics import evaluate_classification
from reporting.report_generator import ReportGenerator

# %% [markdown]
# ## 1. Load Models and Test Data

# %%
# rul_model = XGBoostRULRegressor()
# rul_model.load_model('models/rul_regressor.pkl')
# classifier = XGBoostFailureClassifier()
# classifier.load_model('models/failure_classifier.pkl')
# test = pd.read_csv('data/processed/test_data.csv')
print('Placeholder: Load models')

# %% [markdown]
# ## 2. Evaluate RUL Regression

# %%
# y_pred_rul = rul_model.predict(X_test)
# rul_metrics = evaluate_regression(y_test_rul, y_pred_rul, plot_dir='reports/figures/rul')
# print(rul_metrics)
print('Placeholder: Evaluate RUL model')

# %% [markdown]
# ## 3. Evaluate Failure Classification

# %%
# y_pred_class = classifier.predict(X_test)
# y_proba_class = classifier.predict_proba(X_test)
# class_metrics = evaluate_classification(y_test_class, y_pred_class, y_proba_class, plot_dir='reports/figures/classifier')
# print(class_metrics)
print('Placeholder: Evaluate classifier')

# %% [markdown]
# ## 4. Generate Reports

# %%
# reporter = ReportGenerator(output_dir='reports/evaluation')
# reporter.generate_model_report('RUL_Regressor', rul_metrics, rul_model.get_feature_importance())
# reporter.generate_model_report('Failure_Classifier', class_metrics, classifier.get_feature_importance())
print('Placeholder: Generate reports')

# %% [markdown]
# ## Next Steps
#
# Proceed to **06 - Deployment** for model packaging and deployment.

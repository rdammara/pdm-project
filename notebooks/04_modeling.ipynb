# %% [markdown]
# # 04 - Modeling
#
# **CRISP-DM Phase 4: Modeling**
#
# Train XGBoost models for RUL regression and failure classification.

# %%
import pandas as pd
import numpy as np
import sys, os
sys.path.append(os.path.join(os.path.dirname(os.getcwd()), 'src'))

from modeling.xgb_regressor import XGBoostRULRegressor
from modeling.xgb_classifier import XGBoostFailureClassifier
from utils.helpers import load_config

config = load_config()

# %% [markdown]
# ## 1. Load Processed Data

# %%
# train = pd.read_csv('data/processed/train_data.csv')
# val = pd.read_csv('data/processed/val_data.csv')
# test = pd.read_csv('data/processed/test_data.csv')
print('Placeholder: Load data')

# %% [markdown]
# ## 2. Prepare Features and Targets

# %%
# exclude_cols = ['machine_id', 'timestamp', 'RUL', 'failure_label']
# feature_cols = [col for col in train.columns if col not in exclude_cols]

# X_train = train[feature_cols]
# y_train_rul = train['RUL']
# y_train_class = train['failure_label']
print('Placeholder: Prepare features')

# %% [markdown]
# ## 3. Train RUL Regression Model

# %%
# params = config['modeling']['rul_regression']['params']
# rul_model = XGBoostRULRegressor(params=params)
# rul_model.train(X_train, y_train_rul, X_val, y_val_rul, early_stopping_rounds=10)
# rul_model.save_model('models/rul_regressor.pkl')
print('Placeholder: Train RUL model')

# %% [markdown]
# ## 4. Train Failure Classification Model

# %%
# params = config['modeling']['failure_classification']['params']
# classifier = XGBoostFailureClassifier(params=params)
# classifier.train(X_train, y_train_class, X_val, y_val_class, early_stopping_rounds=10)
# classifier.save_model('models/failure_classifier.pkl')
print('Placeholder: Train classifier')

# %% [markdown]
# ## 5. Feature Importance Analysis

# %%
# top_features = rul_model.get_feature_importance(top_n=20)
# print(top_features)
print('Placeholder: Feature importance')

# %% [markdown]
# ## Next Steps
#
# Proceed to **05 - Evaluation** to assess model performance.
